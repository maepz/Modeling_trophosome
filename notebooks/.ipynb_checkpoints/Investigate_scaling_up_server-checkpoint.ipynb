# %%
# np.random.seed(666)
import pandas as pd
import sys
sys.path.append("../src/")
from alive_progress import alive_bar
from project_package.generate_pop import SymPop
from project_package.generate_pop import generate_initial_pop_unlinked
from project_package.run_model import *
import tracemalloc
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Parallelization
#
# The way it is written now, the model parallelizes over the number of individual hosts; 1cpu/host

# %% [markdown]
# ## toy example [10,40,100] worms + cpus(10 to 1, every 2)
#
# record: time to run one generation, time to run the whole script (incl. writting output files)

# %%
time_df=pd.DataFrame([], columns=['test','nworms','cpus','time_run','time_write','time_tot'])
mylist=[[10,10],[4,10],[2,10],[1,10],
        [10,100],[4,100],[2,100],
        [10,1000],[4,1000],[2,1000],
        [10,10000],[4,10000]
       ]

time_df.iloc[:,0]=['toy_example1_'+str(w)+'worms_'+str(cpus)+'cpus' for cpus,w in mylist]
time_df.iloc[:,1]=[w for cpus,w in mylist]
time_df.iloc[:,2]=[cpus for cpus,w in mylist]
time_df
# Out:
#                               test nworms cpus time_run time_write time_tot
# 0      toy_example1_10worms_10cpus     10   10      NaN        NaN      NaN
# 1       toy_example1_10worms_4cpus     10    4      NaN        NaN      NaN
# 2       toy_example1_10worms_2cpus     10    2      NaN        NaN      NaN
# 3       toy_example1_10worms_1cpus     10    1      NaN        NaN      NaN
# 4     toy_example1_100worms_10cpus    100   10      NaN        NaN      NaN
# 5      toy_example1_100worms_4cpus    100    4      NaN        NaN      NaN
# 6      toy_example1_100worms_2cpus    100    2      NaN        NaN      NaN
# 7    toy_example1_1000worms_10cpus   1000   10      NaN        NaN      NaN
# 8     toy_example1_1000worms_4cpus   1000    4      NaN        NaN      NaN
# 9     toy_example1_1000worms_2cpus   1000    2      NaN        NaN      NaN
# 10  toy_example1_10000worms_10cpus  10000   10      NaN        NaN      NaN
# 11   toy_example1_10000worms_4cpus  10000    4      NaN        NaN      NaN

# %%
import pickle
import pandas as pd
import sys
# sys.path.append("/Users/maeva/Desktop/Modeling_trophosome/src/")
sys.path.append("/home/qiulab/data/CRF_project/work/Modeling_trophosome/src/")

from project_package.generate_pop import generate_initial_pop_unlinked, generate_random_fisherlog_pop_unlinked,generate_random_fisherlog_pop_binomial_tree, SymPop
from project_package.update_pop import update_pop_v1_3
from project_package.run_model import run_generation_of_host_pop_v1_3
from project_package.plot import visualize_pop
from project_package.simplify import merge_graphs

import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import multiprocessing
from alive_progress import alive_bar

import time
import warnings

# import seaborn as sns
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# np.random.seed(666)

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with open('../examples/investigate_scaling_up/toy_example1_times.txt','w') as fa:
    fa.write('')
    
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

    for mytestparams in time_df.values:
    
        test=mytestparams[0]
        
        ## init results objects    
        time_series_freeliving={}
        time_series_hostassociated={}
        
        ## params grow_and_steady
        mutation_rate=1E-12
        growth_factor=1.2
        steady_state_runtime=50
        max_runtime=np.inf
        pop_size_thr=1E4
        simplify=1
        verbose=0
        sampling_rate=1
        
        ## params run_host_pop_gen
        n_worms=mytestparams[1]
        infection_sym_count=10
        tot_host_pop_gen=20
        escape_rate=1E-2
        n_trials=1
        cpus=mytestparams[2]
        
        # init tree log-fisher
        init_pop_strains=100
        is_init_pop_log_fisher=True
        
        if is_init_pop_log_fisher==True:  
            freelivingG=generate_random_fisherlog_pop_unlinked(i=init_pop_strains) #n=individuals, i=strains
            freelivingG=nx.relabel_nodes(freelivingG, dict([[i,'0.0.'+str(i)] for i in range(init_pop_strains)]))
            
        ## init tree
        
        # fitnesses=[0.95,0.9] # allele_id:fitness
        # abundances=[300000000,700000000] # allele_id:abundance # total 1G cells
        # freelivingG=generate_initial_pop_unlinked(fitnesses,abundances)
        # freelivingG=nx.relabel_nodes(freelivingG, {0:'0.0.0',1:'0.0.1'})
        # time_series_freeliving[0]=freelivingG
        
        
        
        
        myparams=['## params grow_and_steady',
        'mutation_rate='+str(mutation_rate),
        'growth_factor='+str(growth_factor),
        'steady_state_runtime='+str(steady_state_runtime),
        'max_runtime='+str(max_runtime),
        'pop_size_thr='+str(pop_size_thr),
        'simplify='+str(simplify),
        'verbose='+str(verbose),
        'sampling_rate='+str(sampling_rate),
        '',
        '## params run_host_pop_gen',
        'n_worms='+str(n_worms),
        'infection_sym_count='+str(infection_sym_count),
        'tot_host_pop_gen='+str(tot_host_pop_gen),
        'escape_rate='+str(escape_rate),
        'n_trials='+str(n_trials),
        'cpus='+str(cpus),
        '',
        '## init tree',
        'init_pop_strains='+str(init_pop_strains),
        'is_init_pop_log_fisher='+str(is_init_pop_log_fisher)]
        
        
        print(SymPop(freelivingG).pop_size)
        time_series_freeliving[0]=freelivingG
        
        
        ###############################
        ## init results objects    
        time_series_freeliving={}
        time_series_hostassociated={}
        print('test=',test,'n_worms=',n_worms,'cpus=',cpus)
        start_time=time.time()
        
        # with alive_bar((tot_host_pop_gen+1) * n_trials ,force_tty=True) as bar:
        for trial in range(n_trials):
            host_pop_gen=0
            time_series_freeliving[trial]=[freelivingG]
            time_series_hostassociated[trial]=[nx.Graph()]
            myfreelivingG=freelivingG.copy()
        
            for host_pop_gen in range(1,tot_host_pop_gen+1):
            
                merged_Graph_hostassociated, merged_Graph_freeliving,_=run_generation_of_host_pop_v1_3(myfreelivingG, n_worms, infection_sym_count,host_pop_gen,escape_rate,
                                     mutation_rate, steady_state_runtime,
                                     max_runtime, growth_factor=growth_factor,
                                     stop_when_fixed=True, pop_size_thr=pop_size_thr, simplify=simplify,
                                     verbose=verbose, t=0,sampling_rate=sampling_rate,nthreads=cpus)
                
                time_series_hostassociated[trial]+=[merged_Graph_hostassociated]
                time_series_freeliving[trial]+=[merged_Graph_freeliving]
                myfreelivingG=merged_Graph_freeliving
                    
                    # bar() 
    
        time_run=time.time()-start_time
        # time_df.loc[time_df.test==test,'time_run']=time_run
        ###########
        
        
        dump_dir='../examples/'
        
        with open(dump_dir+test+'.input_params.txt', 'w') as fa:
            fa.write('\n'.join(myparams))
        
        with open(dump_dir+test+'.time_series_hostassociated.txt', 'wb') as handle:
          pickle.dump(time_series_hostassociated, handle)
        
        with open(dump_dir+test+'.time_series_freeliving.txt', 'wb') as handle:
          pickle.dump(time_series_freeliving, handle)
    
        time_write=time.time()
        # time_df.loc[time_df.test==test,'time_write']=time_write-time_run
    
        # time_df.loc[time_df.test==test,'time_tot']=time_write-start_time
        appended_line='\t'.join([test,str(n_worms),str(cpus),str(time_write-time_run),str(time_run)])
        with open('../examples/investigate_scaling_up/toy_example1_times.txt','a') as fa:
            fa.write(appended_line+'\n')
# Out:
# 1987
# test= toy_example1_10worms_10cpus n_worms= 10 cpus= 10
# 2845
# test= toy_example1_10worms_4cpus n_worms= 10 cpus= 4
# 2465
# test= toy_example1_10worms_2cpus n_worms= 10 cpus= 2
# 4258
# test= toy_example1_10worms_1cpus n_worms= 10 cpus= 1
# 4240
# test= toy_example1_100worms_10cpus n_worms= 100 cpus= 10
# Process ForkPoolWorker-422:
# Process ForkPoolWorker-424:
# Process ForkPoolWorker-425:
# Process ForkPoolWorker-430:
# Process ForkPoolWorker-429:
# Process ForkPoolWorker-421:
# Process ForkPoolWorker-426:
# Process ForkPoolWorker-427:
# Process ForkPoolWorker-428:
# Process ForkPoolWorker-423:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/queues.py", line 377, in put
#     self._writer.send_bytes(obj)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/connection.py", line 405, in _send_bytes
#     self._send(buf)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/run_model.py:221, in run_generation_of_host_pop_v1_3(freelivingG, n_worms, infection_sym_count, host_pop_gen, escape_rate, mutation_rate, steady_state_runtime, max_runtime, growth_factor, pop_size_thr, stop_when_fixed, simplify, verbose, t, sampling_rate, nthreads)
#     220 with multiprocessing.Pool(processes=nthreads) as pool:
# --> 221     Graph_lists=pool.map(grow_and_steady_from_freeliving,args)
#     223 Graph_list_init_intrahost,Graph_list_hostassociated,Graph_list_escapees,results=map(list, zip(*Graph_lists))
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     363 '''
#     364 Apply `func` to each element in `iterable`, collecting the results
#     365 in a list that is returned.
#     366 '''
# --> 367 return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 126
#     122 myfreelivingG=freelivingG.copy()
#     124 for host_pop_gen in range(1,tot_host_pop_gen+1):
# --> 126     merged_Graph_hostassociated, merged_Graph_freeliving,_=run_generation_of_host_pop_v1_3(myfreelivingG, n_worms, infection_sym_count,host_pop_gen,escape_rate,
#     127                          mutation_rate, steady_state_runtime,
#     128                          max_runtime, growth_factor=growth_factor,
#     129                          stop_when_fixed=True, pop_size_thr=pop_size_thr, simplify=simplify,
#     130                          verbose=verbose, t=0,sampling_rate=sampling_rate,nthreads=cpus)
#     132     time_series_hostassociated[trial]+=[merged_Graph_hostassociated]
#     133     time_series_freeliving[trial]+=[merged_Graph_freeliving]
#
# File /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/run_model.py:220, in run_generation_of_host_pop_v1_3(freelivingG, n_worms, infection_sym_count, host_pop_gen, escape_rate, mutation_rate, steady_state_runtime, max_runtime, growth_factor, pop_size_thr, stop_when_fixed, simplify, verbose, t, sampling_rate, nthreads)
#     211 ### parallel phase ###
#     213 args=[{'freelivingG':freelivingG,'alleles':alleles,'abundances':abundances,'fitnesses':fitnesses,
#     214        'host_pop_gen':host_pop_gen, 'host_id':host_id,
#     215       'infection_sym_count':infection_sym_count, 'steady_state_runtime':steady_state_runtime,
#     216       'mutation_rate':mutation_rate,'max_runtime':max_runtime,
#     217       'growth_factor':growth_factor,'pop_size_thr':pop_size_thr,
#     218       'escape_rate':escape_rate,'sampling_rate':1,'verbose':verbose} for host_id in range(n_worms)]
# --> 220 with multiprocessing.Pool(processes=nthreads) as pool:
#     221     Graph_lists=pool.map(grow_and_steady_from_freeliving,args)
#     223 Graph_list_init_intrahost,Graph_list_hostassociated,Graph_list_escapees,results=map(list, zip(*Graph_lists))
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py:739, in Pool.__exit__(self, exc_type, exc_val, exc_tb)
#     738 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 739     self.terminate()
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py:657, in Pool.terminate(self)
#     655 util.debug('terminating pool')
#     656 self._state = TERMINATE
# --> 657 self._terminate()
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/util.py:224, in Finalize.__call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     221 else:
#     222     sub_debug('finalizer calling %s with args %s and kwargs %s',
#     223               self._callback, self._args, self._kwargs)
# --> 224     res = self._callback(*self._args, **self._kwargs)
#     225 self._weakref = self._callback = self._args = \
#     226                 self._kwargs = self._key = None
#     227 return res
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py:724, in Pool._terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     722 util.debug('joining result handler')
#     723 if threading.current_thread() is not result_handler:
# --> 724     result_handler.join()
#     726 if pool and hasattr(pool[0], 'terminate'):
#     727     util.debug('joining pool workers')
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
time_df=pd.read_csv('../examples/investigate_scaling_up/toy_example1_times.txt',sep='\t')
# df=time_df.melt(id_vars=['test','nworms','cpus'])
time_df

# %%
time_df.to_csv('../examples/investigate_scaling_up/toy_example1_times.txt',header=True,sep='\t')

# %%
import seaborn as sns
g = sns.FacetGrid(df[df.nworms<100000], hue="nworms",col='variable',sharey=False)
g.map(sns.lineplot,'cpus','value')
g.map(sns.scatterplot,'cpus','value')

plt.legend()
# ax = g.ax_joint
# ax.set_yscale('log')

# %%
df[(df.cpus==10 )& (df.variable=='time_run')]
# Out:
#                               test nworms cpus  variable        value
# 0      toy_example1_10worms_10cpus     10   10  time_run     5.631855
# 4     toy_example1_100worms_10cpus    100   10  time_run    12.743247
# 7    toy_example1_1000worms_10cpus   1000   10  time_run    127.75503
# 10  toy_example1_10000worms_10cpus  10000   10  time_run  1094.733551

# %%
df[(df.cpus==5 )& (df.variable=='time_run')]
# Out:
# Empty DataFrame
# Columns: [test, nworms, cpus, variable, value]
# Index: []

# %%
df[(df.nworms==10000)& (df.variable=='time_run')]
# Out:
#                               test nworms cpus  variable        value
# 10  toy_example1_10000worms_10cpus  10000   10  time_run  1094.733551
# 11   toy_example1_10000worms_4cpus  10000    4  time_run   1366.06253

# %%
df[(df.nworms==100)& (df.variable=='time_run')]
# Out:
#                            test nworms cpus  variable      value
# 4  toy_example1_100worms_10cpus    100   10  time_run  12.743247
# 5   toy_example1_100worms_4cpus    100    4  time_run  14.554067
# 6   toy_example1_100worms_2cpus    100    2  time_run  16.559118

# %%
time_df
# Out:
#                               test nworms cpus     time_run time_write  \
# 0      toy_example1_10worms_10cpus     10   10     5.631855   0.008554
# 1       toy_example1_10worms_4cpus     10    4     4.676822   0.011056
# 2       toy_example1_10worms_2cpus     10    2     3.295231   0.009697
# 3       toy_example1_10worms_1cpus     10    1     3.051675   0.008913
# 4     toy_example1_100worms_10cpus    100   10    12.743247   0.009149
# 5      toy_example1_100worms_4cpus    100    4    14.554067   0.008538
# 6      toy_example1_100worms_2cpus    100    2    16.559118    0.00999
# 7    toy_example1_1000worms_10cpus   1000   10    127.75503    0.01001
# 8     toy_example1_1000worms_4cpus   1000    4   136.989747   0.011168
# 9     toy_example1_1000worms_2cpus   1000    2   160.798556   0.011547
# 10  toy_example1_10000worms_10cpus  10000   10  1094.733551   0.013162
# 11   toy_example1_10000worms_4cpus  10000    4   1366.06253   0.012449
#
#        time_tot
# 0      5.640409
# 1      4.687878
# 2      3.304928
# 3      3.060587
# 4     12.752395
# 5     14.562605
# 6     16.569107
# 7    127.765039
# 8    137.000914
# 9    160.810103
# 10  1094.746712
# 11  1366.074979

# %% [markdown]
# ## toy example

# %%
time_df=pd.read_csv('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/times.txt',sep='\t',header=0)
df=time_df.melt(id_vars=['test','n_worms','cpus'])
df[df.test.str.contains('toy_example1')]
print(max(df[(df.test.str.contains('toy_example1')) & (df.variable=='run_time')].value.values),
     min(df[(df.test.str.contains('toy_example1')) & (df.variable=='run_time')].value.values))
# Out:
# 1757.9135015010834 2.6209464073181152

# %%
df[df.test.str.contains('toy_example1')]
# Out:
#                               test  n_worms  cpus    variable         value
# 0       toy_example1_40worms_8cpus       40     8  write_time  1.761659e+09
# 1      toy_example1_100worms_1cpus      100     1  write_time  1.761660e+09
# 2    toy_example1_1000worms_10cpus     1000    10  write_time  1.761660e+09
# 3     toy_example1_100worms_20cpus      100    20  write_time  1.761661e+09
# 4     toy_example1_100worms_40cpus      100    40  write_time  1.761661e+09
# 5    toy_example1_1000worms_20cpus     1000    20  write_time  1.761661e+09
# 6    toy_example1_1000worms_40cpus     1000    40  write_time  1.761661e+09
# 7     toy_example1_100worms_10cpus      100    10  write_time  1.761661e+09
# 8      toy_example1_100worms_2cpus      100     2  write_time  1.761661e+09
# 9     toy_example1_1000worms_2cpus     1000     2  write_time  1.761662e+09
# 17  toy_example1_10000worms_10cpus    10000    10  write_time  1.761669e+09
# 18   toy_example1_10000worms_2cpus    10000     2  write_time  1.761669e+09
# 19  toy_example1_10000worms_20cpus    10000    20  write_time  1.761680e+09
# 20      toy_example1_40worms_8cpus       40     8    run_time  2.620946e+00
# 21     toy_example1_100worms_1cpus      100     1    run_time  2.319346e+01
# 22   toy_example1_1000worms_10cpus     1000    10    run_time  8.019696e+01
# 23    toy_example1_100worms_20cpus      100    20    run_time  5.483080e+00
# 24    toy_example1_100worms_40cpus      100    40    run_time  7.673773e+00
# 25   toy_example1_1000worms_20cpus     1000    20    run_time  7.057840e+01
# 26   toy_example1_1000worms_40cpus     1000    40    run_time  6.809885e+01
# 27    toy_example1_100worms_10cpus      100    10    run_time  5.594924e+00
# 28     toy_example1_100worms_2cpus      100     2    run_time  1.145316e+01
# 29    toy_example1_1000worms_2cpus     1000     2    run_time  1.441871e+02
# 37  toy_example1_10000worms_10cpus    10000    10    run_time  1.182174e+03
# 38   toy_example1_10000worms_2cpus    10000     2    run_time  1.757914e+03
# 39  toy_example1_10000worms_20cpus    10000    20    run_time  1.124177e+03

# %%
import seaborn as sns
g = sns.FacetGrid(df[(df.test.str.contains('toy_example1')) & (df.n_worms!=40)], hue="n_worms",col='variable',sharey=False)
g.map(sns.lineplot,'cpus','value')
g.map(sns.scatterplot,'cpus','value')
g.set(yscale='log')
g.set(ylabel='Time (seconds)')

plt.legend(bbox_to_anchor=(1, 1),title="host population size")

# %% [markdown]
# ### Symbiont Pop param vs host pop size

# %%
import pickle
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from project_package.generate_pop import SymPop
import seaborn as sns

fig, axes = plt.subplots(3, 3, figsize=(20, 10), sharex=True, sharey='row')

i=0

for n_worms in [100,1000,10000]:

    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/toy_example1_'+str(n_worms)+'worms_10cpus.time_series_hostassociated.graphs.pickledump', 'rb') as handle:
      time_series_hostassociated=pickle.loads(handle.read())
        
    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/toy_example1_'+str(n_worms)+'worms_10cpus.time_series_freeliving.graphs.pickledump', 'rb') as handle:
      time_series_freeliving=pickle.loads(handle.read())
    
    df=pd.DataFrame()
    for trial in time_series_freeliving.keys():
    
        time_series_hostassociated[trial][0]=nx.Graph(abundance=0)
        df2=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'host-associated',str(trial)] for G in time_series_hostassociated[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df=pd.concat([df, df2])
    
        # if trial==0:
        #     continue
        df3=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'free-living',str(trial)] for G in time_series_freeliving[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df=pd.concat([df, df3])
        
    axes[0,i].set_title('n_worms = '+str(n_worms))
    sns.lineplot(ax=axes[0,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='richness',hue='metapop',legend=True)
    sns.lineplot(ax=axes[1,i], data=df[(df.pop_size>0) & ~(df.eveness.isna())],x=df[(df.pop_size>0) & ~(df.eveness.isna())].index,y='eveness',hue='metapop',legend=False)
    sns.lineplot(ax=axes[2,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='mean_fitness',hue='metapop',legend=False)
    fig.text(0.5, 0.04, 'Host pop generations', ha='center')
    i+=1
# Out:
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)

# %% [markdown]
# ### Symbiont Pop param vs cpus

# %%
import pickle
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from project_package.generate_pop import SymPop
import seaborn as sns

fig, axes = plt.subplots(3, 3, figsize=(20, 10), sharex=True, sharey='row')

i=0

for cpus in [2,10,40]:

    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/toy_example1_1000worms_'+str(cpus)+'cpus.time_series_hostassociated.graphs.pickledump', 'rb') as handle:
      time_series_hostassociated=pickle.loads(handle.read())
        
    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/toy_example1_1000worms_'+str(cpus)+'cpus.time_series_freeliving.graphs.pickledump', 'rb') as handle:
      time_series_freeliving=pickle.loads(handle.read())
    
    df=pd.DataFrame()
    for trial in time_series_freeliving.keys():
    
        time_series_hostassociated[trial][0]=nx.Graph(abundance=0)
        df2=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'host-associated',str(trial)] for G in time_series_hostassociated[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df=pd.concat([df, df2])
    
        # if trial==0:
        #     continue
        df3=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'free-living',str(trial)] for G in time_series_freeliving[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df=pd.concat([df, df3])
    
    axes[0,i].set_title('CPUS = '+str(cpus))
    sns.lineplot(ax=axes[0,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='richness',hue='metapop',legend=True)
    sns.lineplot(ax=axes[1,i], data=df[(df.pop_size>0) & ~(df.eveness.isna())],x=df[(df.pop_size>0) & ~(df.eveness.isna())].index,y='eveness',hue='metapop',legend=False)
    sns.lineplot(ax=axes[2,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='mean_fitness',hue='metapop',legend=False)
    fig.text(0.5, 0.04, 'Host pop generations', ha='center')


    i+=1
# Out:
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)

# %% [markdown]
# ### Symbiont Pop param vs symb diversity (mutation_rate)

# %%
df=time_df[(time_df.n_worms==100) & (time_df.cpus==10)]
df['mutation_rate']=[1E-12,1E-11,1E-10,1E-09,1E-06,1E-03,1E-04,1E-05]
df=df.melt(id_vars=['test','n_worms','cpus','mutation_rate'])
df
# Out:
# /tmp/ipykernel_395135/2260476311.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mutation_rate']=[1E-12,1E-11,1E-10,1E-09,1E-06,1E-03,1E-04,1E-05]
#                             test  n_worms  cpus  mutation_rate    variable  \
# 0   toy_example1_100worms_10cpus      100    10   1.000000e-12  write_time
# 1   toy_example2_100worms_10cpus      100    10   1.000000e-11  write_time
# 2   toy_example3_100worms_10cpus      100    10   1.000000e-10  write_time
# 3   toy_example4_100worms_10cpus      100    10   1.000000e-09  write_time
# 4   toy_example5_100worms_10cpus      100    10   1.000000e-06  write_time
# 5   toy_example6_100worms_10cpus      100    10   1.000000e-03  write_time
# 6   toy_example7_100worms_10cpus      100    10   1.000000e-04  write_time
# 7   toy_example8_100worms_10cpus      100    10   1.000000e-05  write_time
# 8   toy_example1_100worms_10cpus      100    10   1.000000e-12    run_time
# 9   toy_example2_100worms_10cpus      100    10   1.000000e-11    run_time
# 10  toy_example3_100worms_10cpus      100    10   1.000000e-10    run_time
# 11  toy_example4_100worms_10cpus      100    10   1.000000e-09    run_time
# 12  toy_example5_100worms_10cpus      100    10   1.000000e-06    run_time
# 13  toy_example6_100worms_10cpus      100    10   1.000000e-03    run_time
# 14  toy_example7_100worms_10cpus      100    10   1.000000e-04    run_time
# 15  toy_example8_100worms_10cpus      100    10   1.000000e-05    run_time
#
#            value
# 0   1.761661e+09
# 1   1.761663e+09
# 2   1.761663e+09
# 3   1.761663e+09
# 4   1.761664e+09
# 5   1.761664e+09
# 6   1.761664e+09
# 7   1.761665e+09
# 8   5.594924e+00
# 9   5.736174e+00
# 10  6.113664e+00
# 11  5.104293e+00
# 12  6.068246e+00
# 13  1.495412e+02
# 14  1.479006e+01
# 15  7.269935e+00

# %%
import seaborn as sns
g = sns.FacetGrid(df[(df.test.str.contains('toy_example')) & (df.n_worms!=40)],col='variable',sharey=False)
g.map(sns.scatterplot,'mutation_rate','value')
g.map(sns.lineplot,'mutation_rate','value')

g.set(yscale='log',xscale='log')
g.set(ylabel='Time (seconds)')

print(df[df.variable=='run_time'].sort_values('mutation_rate').test.values)
# Out:
# ['toy_example1_100worms_10cpus' 'toy_example2_100worms_10cpus'
#  'toy_example3_100worms_10cpus' 'toy_example4_100worms_10cpus'
#  'toy_example5_100worms_10cpus' 'toy_example8_100worms_10cpus'
#  'toy_example7_100worms_10cpus' 'toy_example6_100worms_10cpus']

# %%
import pickle
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from project_package.generate_pop import SymPop
import seaborn as sns

fig, axes = plt.subplots(3, 3, figsize=(20, 10), sharex=True, sharey='row')

i=0

df=time_df[(time_df.n_worms==100) & (time_df.cpus==10)]
df['mutation_rate']=[1E-12,1E-11,1E-10,1E-09,1E-06,1E-03,1E-04,1E-05]
mydf=df.melt(id_vars=['test','n_worms','cpus','mutation_rate'])

for mytest in mydf[mydf.variable=='run_time'].sort_values('mutation_rate').test.values[-3:]:
    mutation_rate=mydf[mydf.test==mytest].mutation_rate.values[0]
    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/'+mytest+'.time_series_hostassociated.graphs.pickledump', 'rb') as handle:
      time_series_hostassociated=pickle.loads(handle.read())
        
    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/'+mytest+'.time_series_freeliving.graphs.pickledump', 'rb') as handle:
      time_series_freeliving=pickle.loads(handle.read())
    
    df=pd.DataFrame()
    for trial in time_series_freeliving.keys():
    
        time_series_hostassociated[trial][0]=nx.Graph(abundance=0)
        df2=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'host-associated',str(trial)] for G in time_series_hostassociated[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df=pd.concat([df, df2])
    
        # if trial==0:
        #     continue
        df3=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'free-living',str(trial)] for G in time_series_freeliving[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df=pd.concat([df, df3])
    
    axes[0,i].set_title('mutation_rate = '+str(mutation_rate))
    sns.lineplot(ax=axes[0,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='richness',hue='metapop',legend=True)
    sns.lineplot(ax=axes[1,i], data=df[(df.pop_size>0) & ~(df.eveness.isna())],x=df[(df.pop_size>0) & ~(df.eveness.isna())].index,y='eveness',hue='metapop',legend=False)
    sns.lineplot(ax=axes[2,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='mean_fitness',hue='metapop',legend=False)
    fig.text(0.5, 0.04, 'Host pop generations', ha='center')


    i+=1
# Out:
# /tmp/ipykernel_395135/2492240661.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mutation_rate']=[1E-12,1E-11,1E-10,1E-09,1E-06,1E-03,1E-04,1E-05]
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)

# %%
import pickle
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from project_package.generate_pop import SymPop
import seaborn as sns

fig, axes = plt.subplots(3, 3, figsize=(20, 10), sharex=True, sharey='row')

i=0

df=time_df[(time_df.n_worms==100) & (time_df.cpus==10)]
df['mutation_rate']=[1E-12,1E-11,1E-10,1E-09,1E-06,1E-03,1E-04,1E-05]
mydf=df.melt(id_vars=['test','n_worms','cpus','mutation_rate'])

for mytest in mydf[mydf.variable=='run_time'].sort_values('mutation_rate').test.values[-4:-1]:
    mutation_rate=mydf[mydf.test==mytest].mutation_rate.values[0]
    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/'+mytest+'.time_series_hostassociated.graphs.pickledump', 'rb') as handle:
      time_series_hostassociated=pickle.loads(handle.read())
        
    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/'+mytest+'.time_series_freeliving.graphs.pickledump', 'rb') as handle:
      time_series_freeliving=pickle.loads(handle.read())
    
    df=pd.DataFrame()
    for trial in time_series_freeliving.keys():
    
        time_series_hostassociated[trial][0]=nx.Graph(abundance=0)
        df2=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'host-associated',str(trial)] for G in time_series_hostassociated[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df=pd.concat([df, df2])
    
        # if trial==0:
        #     continue
        df3=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'free-living',str(trial)] for G in time_series_freeliving[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df=pd.concat([df, df3])
    
    axes[0,i].set_title('mutation_rate = '+str(mutation_rate))
    sns.lineplot(ax=axes[0,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='richness',hue='metapop',legend=True)
    sns.lineplot(ax=axes[1,i], data=df[(df.pop_size>0) & ~(df.eveness.isna())],x=df[(df.pop_size>0) & ~(df.eveness.isna())].index,y='eveness',hue='metapop',legend=False)
    sns.lineplot(ax=axes[2,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='mean_fitness',hue='metapop',legend=False)
    fig.text(0.5, 0.04, 'Host pop generations', ha='center')


    i+=1
# Out:
# /tmp/ipykernel_395135/1059071298.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mutation_rate']=[1E-12,1E-11,1E-10,1E-09,1E-06,1E-03,1E-04,1E-05]
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:129: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)

# %% [markdown]
# # Using tskit

# %% [markdown]
# ## toy_example1 and different nworms and cpus

# %%
import pandas as pd
import sys
sys.path.append("../src/")
from alive_progress import alive_bar
from project_package.simplify import remove_empty_leaves_and_rescale_edges,remove_empty_leaves, subsample_pop,merge_graphs
from project_package.update_pop import *
from project_package.tskit_functions import *
from project_package.generate_pop import SymPop
from project_package.plot import visualize_pop

import networkx as nx
import time
import multiprocessing

import matplotlib.pyplot as plt

import tracemalloc
import time
import numpy as np
import seaborn as sns
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
time_df=pd.DataFrame([], columns=['test','nworms','cpus','time_run','time_write','time_tot'])
mylist=[[10,10],[4,10],[2,10],[1,10],
        [10,100],[4,100],[2,100],
        [10,1000],[4,1000],[2,1000],
        [10,10000],[4,10000]
       ]

time_df.iloc[:,0]=['toy_example1_'+str(w)+'worms_'+str(cpus)+'cpus' for cpus,w in mylist]
time_df.iloc[:,1]=[w for cpus,w in mylist]
time_df.iloc[:,2]=[cpus for cpus,w in mylist]
time_df
# Out:
#                               test nworms cpus time_run time_write time_tot
# 0      toy_example1_10worms_10cpus     10   10      NaN        NaN      NaN
# 1       toy_example1_10worms_4cpus     10    4      NaN        NaN      NaN
# 2       toy_example1_10worms_2cpus     10    2      NaN        NaN      NaN
# 3       toy_example1_10worms_1cpus     10    1      NaN        NaN      NaN
# 4     toy_example1_100worms_10cpus    100   10      NaN        NaN      NaN
# 5      toy_example1_100worms_4cpus    100    4      NaN        NaN      NaN
# 6      toy_example1_100worms_2cpus    100    2      NaN        NaN      NaN
# 7    toy_example1_1000worms_10cpus   1000   10      NaN        NaN      NaN
# 8     toy_example1_1000worms_4cpus   1000    4      NaN        NaN      NaN
# 9     toy_example1_1000worms_2cpus   1000    2      NaN        NaN      NaN
# 10  toy_example1_10000worms_10cpus  10000   10      NaN        NaN      NaN
# 11   toy_example1_10000worms_4cpus  10000    4      NaN        NaN      NaN

# %%
import pickle
import pandas as pd
import sys
# sys.path.append("/Users/maeva/Desktop/Modeling_trophosome/src/")
sys.path.append("/home/qiulab/data/CRF_project/work/Modeling_trophosome/src/")

from project_package.generate_pop import generate_initial_pop_unlinked, generate_random_fisherlog_pop_unlinked,generate_random_fisherlog_pop_binomial_tree, SymPop
from project_package.run_model import run_generation_of_host_pop_v2_1
from project_package.plot import visualize_pop
from project_package.simplify import merge_graphs

import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import multiprocessing
from alive_progress import alive_bar

import time
import warnings

# import seaborn as sns
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# np.random.seed(666)

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with open('../examples/tskit/toy_example1_times.txt','w') as fa:
    fa.write('')
    
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

    for mytestparams in time_df.values:
    
        test=mytestparams[0]
        
        ## init results objects    
        time_series_freeliving={}
        time_series_hostassociated={}
        
        ## params grow
        mutation_rate=1E-12
        pop_size_thr=1E4
        
        ## params run_host_pop_gen
        n_worms=mytestparams[1]
        infection_sym_count=10
        tot_host_pop_gen=20
        escape_rate=1E-2
        n_trials=1
        cpus=mytestparams[2]
        
        # init tree log-fisher
        init_pop_strains=100
        is_init_pop_log_fisher=True
        
        if is_init_pop_log_fisher==True:  
            freelivingG=generate_random_fisherlog_pop_unlinked(i=init_pop_strains) #n=individuals, i=strains
            freelivingG=nx.relabel_nodes(freelivingG, dict([[i,'0.0.'+str(i)] for i in range(init_pop_strains)]))
            
        ## init tree
        
        # fitnesses=[0.95,0.9] # allele_id:fitness
        # abundances=[300000000,700000000] # allele_id:abundance # total 1G cells
        # freelivingG=generate_initial_pop_unlinked(fitnesses,abundances)
        # freelivingG=nx.relabel_nodes(freelivingG, {0:'0.0.0',1:'0.0.1'})
        # time_series_freeliving[0]=freelivingG
        
        
        
        
        myparams=['## params grow_and_steady',
        'mutation_rate='+str(mutation_rate),
        'pop_size_thr='+str(pop_size_thr),
        '',
        '## params run_host_pop_gen',
        'n_worms='+str(n_worms),
        'infection_sym_count='+str(infection_sym_count),
        'tot_host_pop_gen='+str(tot_host_pop_gen),
        'escape_rate='+str(escape_rate),
        'n_trials='+str(n_trials),
        'cpus='+str(cpus),
        '',
        '## init tree',
        'init_pop_strains='+str(init_pop_strains),
        'is_init_pop_log_fisher='+str(is_init_pop_log_fisher)]
        
        
        print(SymPop(freelivingG).pop_size)
        time_series_freeliving[0]=freelivingG
        
        
        ###############################
        ## init results objects    
        time_series_freeliving={}
        time_series_hostassociated={}
        print('test=',test,'n_worms=',n_worms,'cpus=',cpus)
        start_time=time.time()
        
        # with alive_bar((tot_host_pop_gen+1) * n_trials ,force_tty=True) as bar:
        for trial in range(n_trials):
            host_pop_gen=0
            time_series_freeliving[trial]=[freelivingG]
            time_series_hostassociated[trial]=[nx.Graph()]
            myfreelivingG=freelivingG.copy()
        
            for host_pop_gen in range(1,tot_host_pop_gen+1):
            
                merged_Graph_hostassociated, merged_Graph_freeliving=run_generation_of_host_pop_v2_1(myfreelivingG, n_worms, infection_sym_count,host_pop_gen,escape_rate,
                                     mutation_rate, pop_size_thr=pop_size_thr, nthreads=cpus)
                
                time_series_hostassociated[trial]+=[merged_Graph_hostassociated]
                time_series_freeliving[trial]+=[merged_Graph_freeliving]
                myfreelivingG=merged_Graph_freeliving
                    
                    # bar() 
    
        time_run=time.time()-start_time
        ###########
        
        
        dump_dir='../examples/tskit/'
        
        with open(dump_dir+test+'.input_params.txt', 'w') as fa:
            fa.write('\n'.join(myparams))
        
        with open(dump_dir+test+'.time_series_hostassociated.txt', 'wb') as handle:
          pickle.dump(time_series_hostassociated, handle)
        
        with open(dump_dir+test+'.time_series_freeliving.txt', 'wb') as handle:
          pickle.dump(time_series_freeliving, handle)
    
        time_write=time.time()
        appended_line='\t'.join([test,str(n_worms),str(cpus),str(time_write-time_run),str(time_run)])
        with open('../examples/tskit/toy_example1_times.txt','a') as fa:
            fa.write(appended_line+'\n')
# Out:
# 3633
# test= toy_example1_10worms_10cpus n_worms= 10 cpus= 10
# 2348
# test= toy_example1_10worms_4cpus n_worms= 10 cpus= 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 113
#     109 myfreelivingG=freelivingG.copy()
#     111 for host_pop_gen in range(1,tot_host_pop_gen+1):
# --> 113     merged_Graph_hostassociated, merged_Graph_freeliving=run_generation_of_host_pop_v2_1(myfreelivingG, n_worms, infection_sym_count,host_pop_gen,escape_rate,
#     114                          mutation_rate, pop_size_thr=pop_size_thr, nthreads=cpus)
#     116     time_series_hostassociated[trial]+=[merged_Graph_hostassociated]
#     117     time_series_freeliving[trial]+=[merged_Graph_freeliving]
#
# File /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/run_model.py:104, in run_generation_of_host_pop_v2_1(freelivingG, n_worms, infection_sym_count, host_pop_gen, escape_rate, mutation_rate, pop_size_thr, t, nthreads)
#      96 args=[{'freelivingG':freelivingG,'alleles':alleles,'abundances':abundances,'fitnesses':fitnesses,
#      97        'host_pop_gen':host_pop_gen, 'host_id':host_id,
#      98       'infection_sym_count':infection_sym_count,
#      99       'mutation_rate':mutation_rate,'pop_size_thr':pop_size_thr,
#     100       'escape_rate':escape_rate} for host_id in range(n_worms)]
#     103 with multiprocessing.Pool(processes=nthreads) as pool:
# --> 104     Graph_lists=pool.map(grow_from_freeliving_with_coalescent_v1,args)
#     106 Graph_list_init_intrahost,Graph_list_hostassociated,Graph_list_escapees=map(list, zip(*Graph_lists))
#     109 # #### looped ###
#     110 # Graph_list_init_intrahost=[]
#     111 # Graph_list_hostassociated=[]
#    (...)
#     120
#     121 # get the initial host-associated symbiont meta-pop
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/.conda/envs/mamba/envs/maeva_env/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## toy_example 2-9 increasing mutation rate

# %%
# %%bash
#
# sendjob run_toy_exampleN.sh {example_number} {mutation_rate}

# %% [markdown]
# # Graphs

# %%
time_df1=pd.read_csv('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/times.txt',header=0,sep='\t')
time_df1['code_version']='v1_3'

time_df2=pd.read_csv('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2026_02_10/times.txt',header=0,sep='\t')
time_df2['code_version']='v2_1'

time_df3=pd.read_csv('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2026_02_12/times.txt',header=0,sep='\t')
time_df3['code_version']='v2_2'

time_df4=pd.read_csv('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/V1_4/2026_02_12/times.txt',header=0,sep='\t')
time_df4['code_version']='v1_4'

time_df=pd.concat([time_df1,time_df2,time_df3,time_df4],ignore_index=True)
mutation_rate_dic={'1':1e-12,'2':1e-11,'3':1e-10,'4':1e-9,'5':1e-6,'6':1e-3,'7':1e-4,'8':1e-5}
intrahost_pop_dic={'1':1e4,'10':1e5,'11':1e6,'12':1e7,'13':1e8,'14':1e9,'15':1e10,'16':1e11,'17':1e12}
time_df['toy_example_id']=time_df.test.str.split('_').str[1].str.replace('example','')
time_df['mutation_rate']=time_df.toy_example_id.map(lambda x: mutation_rate_dic.get(x, 1e-12))
time_df['intrahost_pop']=time_df.toy_example_id.map(lambda x: intrahost_pop_dic.get(x, 1e4))

df=time_df.melt(id_vars=['test','n_worms','cpus','code_version','toy_example_id','mutation_rate','intrahost_pop'])
df[:-4]
# Out:
#                               test  n_worms  cpus code_version toy_example_id  \
# 0       toy_example1_40worms_8cpus       40     8         v1_3              1
# 1      toy_example1_100worms_1cpus      100     1         v1_3              1
# 2    toy_example1_1000worms_10cpus     1000    10         v1_3              1
# 3     toy_example1_100worms_20cpus      100    20         v1_3              1
# 4     toy_example1_100worms_40cpus      100    40         v1_3              1
# ..                             ...      ...   ...          ...            ...
# 177   toy_example1_100worms_10cpus      100    10         v1_4              1
# 178    toy_example1_100worms_4cpus      100     4         v1_4              1
# 179    toy_example1_100worms_2cpus      100     2         v1_4              1
# 180  toy_example1_1000worms_40cpus     1000    40         v1_4              1
# 181  toy_example1_1000worms_20cpus     1000    20         v1_4              1
#
#      mutation_rate  intrahost_pop    variable         value
# 0     1.000000e-12        10000.0  write_time  1.761659e+09
# 1     1.000000e-12        10000.0  write_time  1.761660e+09
# 2     1.000000e-12        10000.0  write_time  1.761660e+09
# 3     1.000000e-12        10000.0  write_time  1.761661e+09
# 4     1.000000e-12        10000.0  write_time  1.761661e+09
# ..             ...            ...         ...           ...
# 177   1.000000e-12        10000.0    run_time  1.142173e+01
# 178   1.000000e-12        10000.0    run_time  1.903717e+01
# 179   1.000000e-12        10000.0    run_time  2.550498e+01
# 180   1.000000e-12        10000.0    run_time  9.001684e+01
# 181   1.000000e-12        10000.0    run_time  7.058787e+01
#
# [182 rows x 9 columns]

# %%
time_df[time_df.toy_example_id.astype(int)>1][-4:]
# Out:
#                              test  n_worms  cpus    write_time    run_time  \
# 74   toy_example5_100worms_10cpus      100    10  1.770882e+09   13.547477
# 75   toy_example7_100worms_10cpus      100    10  1.770882e+09    9.668145
# 76   toy_example8_100worms_10cpus      100    10  1.770882e+09   11.933150
# 77  toy_example18_100worms_10cpus      100    10  1.770882e+09  298.037770
#
#    code_version toy_example_id  mutation_rate  intrahost_pop
# 74         v1_4              5   1.000000e-06        10000.0
# 75         v1_4              7   1.000000e-04        10000.0
# 76         v1_4              8   1.000000e-05        10000.0
# 77         v1_4             18   1.000000e-12        10000.0

# %%
df[(df.code_version=='v2_2' )& (df.variable=='run_time')]
# Out:
#                                test  n_worms  cpus code_version  \
# 148     toy_example1_10worms_10cpus       10    10         v2_2
# 149     toy_example1_10worms_10cpus       10    10         v2_2
# 150      toy_example1_10worms_4cpus       10     4         v2_2
# 151      toy_example1_10worms_1cpus       10     1         v2_2
# 152      toy_example1_10worms_2cpus       10     2         v2_2
# 153    toy_example1_100worms_40cpus      100    40         v2_2
# 154    toy_example1_100worms_10cpus      100    10         v2_2
# 155    toy_example1_100worms_10cpus      100    10         v2_2
# 156    toy_example1_100worms_20cpus      100    20         v2_2
# 157     toy_example1_100worms_2cpus      100     2         v2_2
# 158     toy_example1_100worms_4cpus      100     4         v2_2
# 159   toy_example1_1000worms_10cpus     1000    10         v2_2
# 160   toy_example1_1000worms_40cpus     1000    40         v2_2
# 161   toy_example1_1000worms_20cpus     1000    20         v2_2
# 162   toy_example1_1000worms_10cpus     1000    10         v2_2
# 163    toy_example8_100worms_10cpus      100    10         v2_2
# 164    toy_example1_1000worms_4cpus     1000     4         v2_2
# 165  toy_example1_10000worms_20cpus    10000    20         v2_2
# 166  toy_example1_10000worms_10cpus    10000    10         v2_2
#
#     toy_example_id  mutation_rate  intrahost_pop  variable        value
# 148              1   1.000000e-12        10000.0  run_time     8.389551
# 149              1   1.000000e-12        10000.0  run_time     9.375502
# 150              1   1.000000e-12        10000.0  run_time    14.720543
# 151              1   1.000000e-12        10000.0  run_time    31.997809
# 152              1   1.000000e-12        10000.0  run_time    20.758575
# 153              1   1.000000e-12        10000.0  run_time    23.815499
# 154              1   1.000000e-12        10000.0  run_time    32.975580
# 155              1   1.000000e-12        10000.0  run_time    33.824805
# 156              1   1.000000e-12        10000.0  run_time    24.817920
# 157              1   1.000000e-12        10000.0  run_time   147.603091
# 158              1   1.000000e-12        10000.0  run_time    86.726918
# 159              1   1.000000e-12        10000.0  run_time   315.480879
# 160              1   1.000000e-12        10000.0  run_time   116.568697
# 161              1   1.000000e-12        10000.0  run_time   171.113017
# 162              1   1.000000e-12        10000.0  run_time   284.785040
# 163              8   1.000000e-05        10000.0  run_time    45.098185
# 164              1   1.000000e-12        10000.0  run_time   728.356525
# 165              1   1.000000e-12        10000.0  run_time  1461.937602
# 166              1   1.000000e-12        10000.0  run_time  2770.714318

# %%
print(' '.join(map(str,time_df.loc[(time_df.code_version=='v2_1') & (time_df.toy_example_id=='1'),['n_worms','cpus']].sort_values('n_worms').values.flatten())))
# Out:
# 10 10 10 4 10 1 10 2 100 40 100 10 100 10 100 20 100 2 100 4 1000 10 1000 40 1000 20 1000 10 1000 4 10000 20 10000 10

# %% [markdown]
# ## n_worms vs CPUS

# %%
import seaborn as sns
g = sns.FacetGrid(df[(df.test.str.contains('toy_example1_')) & (df.n_worms!=40) & (df.variable=='run_time')], hue="code_version",col='n_worms',sharey=False)
g.map(sns.lineplot,'cpus','value')
g.map(sns.scatterplot,'cpus','value')
g.set(yscale='log')
g.set(ylabel='Time (seconds)')

g.add_legend(title="code_version")
# g.legend(title="host population size")
# Out:
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()

# %%
import seaborn as sns
g = sns.FacetGrid(df[(df.test.str.contains('toy_example1_')) & (df.n_worms!=40) & (df.variable=='run_time')], hue="n_worms",col='code_version',sharey=True)
g.map(sns.lineplot,'cpus','value')
g.map(sns.scatterplot,'cpus','value')
g.set(yscale='log')
g.set(ylabel='Time (seconds)')

g.add_legend(title="n_worms")
# g.legend(title="host population size")
# Out:
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()

# %% [markdown]
# ## Mutation_rate as proxy of genetic diversity

# %%
import seaborn as sns
g = sns.FacetGrid(df[(df.test.str.contains('toy_example')) & (df.intrahost_pop==10000) & (df.n_worms==100) & (df.cpus==10) & (df.variable=='run_time') & (df.toy_example_id!='18')], hue="code_version",col='code_version',sharey=True)
g.map(sns.lineplot,'mutation_rate','value')
g.map(sns.scatterplot,'mutation_rate','value')
g.set(yscale='log')
g.set(ylabel='Time (seconds)')
g.set(xscale='log')
g.add_legend(title="code_version")
# g.legend(title="host population size")
# Out:
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()

# %% [markdown]
# ### sanity check
# mutation rate is used as a proxy for genetic diversity. Lets check if genetic diversity increase in V2_1

# %%
df=time_df.melt(id_vars=['test','n_worms','cpus','code_version','mutation_rate','intrahost_pop'])
mydf=df[(df.test.str.contains('toy_example')) & (df.intrahost_pop==10000) & (df.n_worms==100) & (df.cpus==10) & (df.variable=='run_time') & (df.code_version=='v2_1')]
myfiles=mydf.test.values[:-1]
myfiles
# Out:
# array(['toy_example1_100worms_10cpus', 'toy_example2_100worms_10cpus',
#        'toy_example3_100worms_10cpus', 'toy_example4_100worms_10cpus',
#        'toy_example5_100worms_10cpus', 'toy_example8_100worms_10cpus',
#        'toy_example7_100worms_10cpus', 'toy_example6_100worms_10cpus'],
#       dtype=object)

# %%
import pickle
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from project_package.generate_pop import SymPop
import seaborn as sns

fig, axes = plt.subplots(3, 3, figsize=(20, 10), sharex=True, sharey='row')

i=0


for mytest in myfiles[[4,5,6]]:
    mutation_rate=mydf[mydf.test==mytest].mutation_rate.values[0]

    ### get data from V1_3
    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/'+mytest+'.time_series_hostassociated.graphs.pickledump', 'rb') as handle:
      time_series_hostassociated=pickle.loads(handle.read())
        
    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/'+mytest+'.time_series_freeliving.graphs.pickledump', 'rb') as handle:
      time_series_freeliving=pickle.loads(handle.read())
    
    df=pd.DataFrame()
    for trial in time_series_freeliving.keys():
    
        time_series_hostassociated[trial][0]=nx.Graph(abundance=0)
        df2=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'host-associated',str(trial)] for G in time_series_hostassociated[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df2['code_version']='v1_3'
        df=pd.concat([df, df2])
    
        # if trial==0:
        #     continue
        df3=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'free-living',str(trial)] for G in time_series_freeliving[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df3['code_version']='v1_3'
        df=pd.concat([df, df3])

    ### get data from V2_1
    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2026_02_10/'+mytest+'.time_series_hostassociated.graphs.pickledump', 'rb') as handle:
      time_series_hostassociated=pickle.loads(handle.read())
        
    with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2026_02_10/'+mytest+'.time_series_freeliving.graphs.pickledump', 'rb') as handle:
      time_series_freeliving=pickle.loads(handle.read())
    
    for trial in time_series_freeliving.keys():
    
        time_series_hostassociated[trial][0]=nx.Graph(abundance=0)
        df2=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'host-associated',str(trial)] for G in time_series_hostassociated[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df2['code_version']='v2_1'
        df=pd.concat([df, df2])
    
        # if trial==0:
        #     continue
        df3=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'free-living',str(trial)] for G in time_series_freeliving[trial]],
                                columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
        df3['code_version']='v2_1'
        df=pd.concat([df, df3])
    
    axes[0,i].set_title('mutation_rate = '+str(mutation_rate))
    sns.lineplot(ax=axes[0,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='richness',hue='metapop',style='code_version',legend=True)
    sns.lineplot(ax=axes[1,i], data=df[(df.pop_size>0) & ~(df.eveness.isna())],x=df[(df.pop_size>0) & ~(df.eveness.isna())].index,y='eveness',hue='metapop',style='code_version',legend=False)
    sns.lineplot(ax=axes[2,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='mean_fitness',hue='metapop',style='code_version',legend=False)
    fig.text(0.5, 0.04, 'Host pop generations', ha='center')


    i+=1
# Out:
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:131: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:131: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:131: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:131: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:131: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:131: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)

# %%
import pickle
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from project_package.generate_pop import SymPop
import seaborn as sns

fig, axes = plt.subplots(3, 2, figsize=(20, 10), sharex=True, sharey='row')

i=0

myGs_host_associated={}
myGs_free_living={}

mutation_rate=mydf[mydf.test==myfiles[7]].mutation_rate.values[0]
df=pd.DataFrame()
### get data from V2_1
with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2026_02_10/'+myfiles[7]+'.time_series_hostassociated.graphs.pickledump', 'rb') as handle:
  time_series_hostassociated=pickle.loads(handle.read())
    
with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2026_02_10/'+myfiles[7]+'.time_series_freeliving.graphs.pickledump', 'rb') as handle:
  time_series_freeliving=pickle.loads(handle.read())

myGs_free_living['v2_1']=[time_series_freeliving[0][0]]
myGs_free_living['v2_1']+=[time_series_freeliving[0][20]]
myGs_host_associated['v2_1']=time_series_hostassociated[0][20]

for trial in time_series_freeliving.keys():

    time_series_hostassociated[trial][0]=nx.Graph(abundance=0)
    df2=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'host-associated',str(trial)] for G in time_series_hostassociated[trial]],
                            columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
    df2['code_version']='v2_1'
    df=pd.concat([df, df2])

    df3=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'free-living',str(trial)] for G in time_series_freeliving[trial]],
                            columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
    df3['code_version']='v2_1'
    df=pd.concat([df, df3])

axes[0,i].set_title('mutation_rate = '+str(mutation_rate))
sns.lineplot(ax=axes[0,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='richness',hue='metapop',style='code_version',legend=True)
sns.lineplot(ax=axes[1,i], data=df[(df.pop_size>0) & ~(df.eveness.isna())],x=df[(df.pop_size>0) & ~(df.eveness.isna())].index,y='eveness',hue='metapop',style='code_version',legend=False)
sns.lineplot(ax=axes[2,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='mean_fitness',hue='metapop',style='code_version',legend=False)
axes[0, i].set_ylim(0, 900)
axes[1, i].set_ylim(0, 0.8)
axes[2, i].set_ylim(0.5, 1.3)
# fig.text(0.5, 0.04, 'Host pop generations', ha='center')


i+=1


mutation_rate=mydf[mydf.test==myfiles[6]].mutation_rate.values[0]
df=pd.DataFrame()

### get data from V1_3
with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/'+myfiles[6]+'.time_series_hostassociated.graphs.pickledump', 'rb') as handle:
  time_series_hostassociated=pickle.loads(handle.read())
    
with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2025_10_28/'+myfiles[6]+'.time_series_freeliving.graphs.pickledump', 'rb') as handle:
  time_series_freeliving=pickle.loads(handle.read())

myGs_free_living['v1_3']=[time_series_freeliving[0][0]]
myGs_free_living['v1_3']+=[time_series_freeliving[0][20]]

myGs_host_associated['v1_3']=time_series_hostassociated[0][20]

for trial in time_series_freeliving.keys():

    time_series_hostassociated[trial][0]=nx.Graph(abundance=0)
    df2=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'host-associated',str(trial)] for G in time_series_hostassociated[trial]],
                            columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
    df2['code_version']='v2_1'
    df=pd.concat([df, df2])

    # if trial==0:
    #     continue
    df3=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'free-living',str(trial)] for G in time_series_freeliving[trial]],
                            columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
    df3['code_version']='v2_1'
    df=pd.concat([df, df3])

axes[0,i].set_title('mutation_rate = '+str(mutation_rate))
sns.lineplot(ax=axes[0,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='richness',hue='metapop',style='code_version',legend=True)
sns.lineplot(ax=axes[1,i], data=df[(df.pop_size>0) & ~(df.eveness.isna())],x=df[(df.pop_size>0) & ~(df.eveness.isna())].index,y='eveness',hue='metapop',style='code_version',legend=False)
sns.lineplot(ax=axes[2,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='mean_fitness',hue='metapop',style='code_version',legend=False)
axes[0, i].set_ylim(0, 900)
axes[1, i].set_ylim(0, 0.8)
axes[2, i].set_ylim(0.5, 1.3)
fig.text(0.5, 0.04, 'Host pop generations', ha='center')
# Out:
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:131: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:131: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# Text(0.5, 0.04, 'Host pop generations')

# %%
from project_package.generate_pop import SymPop

for k,G_list in myGs_free_living.items():
    print(k)
    plt.figure()
    SymPop(G_list[0]).visualize_pop(replace_title=k+'_'+"gen0",view_node_labels=False)
    plt.figure()
    SymPop(G_list[1]).visualize_pop(replace_title=k+'_'+"gen20",view_node_labels=False)
# Out:
# v3
# v1

# %%
from project_package.generate_pop import SymPop

for k,G in myGs_host_associated.items():
    print(k)
    plt.figure()
    SymPop(G).visualize_pop(replace_title=k,view_node_labels=False)
# Out:
# v3
# v1

# %%
import pickle
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from project_package.generate_pop import SymPop
import seaborn as sns

fig, axes = plt.subplots(3, 2, figsize=(20, 10), sharex=True, sharey='row')

i=0

myGs_host_associated={}
myGs_free_living={}

df=pd.DataFrame()
### get data from V2_2
trial='toy_example8_100worms_10cpus'
mutation_rate=mydf[mydf.test==trial].mutation_rate.values[0]

with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2026_02_12/'+trial+'.time_series_hostassociated.graphs.pickledump', 'rb') as handle:
  time_series_hostassociated=pickle.loads(handle.read())
    
with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/2026_02_12/'+trial+'.time_series_freeliving.graphs.pickledump', 'rb') as handle:
  time_series_freeliving=pickle.loads(handle.read())

myGs_free_living['v2_2']=[time_series_freeliving[0][0]]
myGs_free_living['v2_2']+=[time_series_freeliving[0][20]]
myGs_host_associated['v2_2']=time_series_hostassociated[0][20]

for trial in time_series_freeliving.keys():

    time_series_hostassociated[trial][0]=nx.Graph(abundance=0)
    df2=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'host-associated',str(trial)] for G in time_series_hostassociated[trial]],
                            columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
    df2['code_version']='v2_2'
    df=pd.concat([df, df2])

    df3=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'free-living',str(trial)] for G in time_series_freeliving[trial]],
                            columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
    df3['code_version']='v2_2'
    df=pd.concat([df, df3])

axes[0,i].set_title('code_version='+'v2_2 '+'mutation_rate = '+str(mutation_rate))
sns.lineplot(ax=axes[0,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='richness',hue='metapop',style='code_version',legend=True)
sns.lineplot(ax=axes[1,i], data=df[(df.pop_size>0) & ~(df.eveness.isna())],x=df[(df.pop_size>0) & ~(df.eveness.isna())].index,y='eveness',hue='metapop',style='code_version',legend=False)
sns.lineplot(ax=axes[2,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='mean_fitness',hue='metapop',style='code_version',legend=False)
axes[0, i].set_ylim(0, 900)
axes[1, i].set_ylim(0, 0.8)
axes[2, i].set_ylim(0.5, 1.3)
# fig.text(0.5, 0.04, 'Host pop generations', ha='center')


i+=1


df=pd.DataFrame()

### get data from V1_4
trial='toy_example7_100worms_10cpus'
mutation_rate=mydf[mydf.test==trial].mutation_rate.values[0]

with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/V1_4/2026_02_12/'+trial+'.time_series_hostassociated.graphs.pickledump', 'rb') as handle:
  time_series_hostassociated=pickle.loads(handle.read())
    
with open('/home/qiulab/data/CRF_project/scratch/Modeling_trophosome/Scaling_up_investigation/V1_4/2026_02_12/'+trial+'.time_series_freeliving.graphs.pickledump', 'rb') as handle:
  time_series_freeliving=pickle.loads(handle.read())

myGs_free_living['v1_4']=[time_series_freeliving[0][0]]
myGs_free_living['v1_4']+=[time_series_freeliving[0][20]]

myGs_host_associated['v1_4']=time_series_hostassociated[0][20]

for trial in time_series_freeliving.keys():

    time_series_hostassociated[trial][0]=nx.Graph(abundance=0)
    df2=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'host-associated',str(trial)] for G in time_series_hostassociated[trial]],
                            columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
    df2['code_version']='v1_4'
    df=pd.concat([df, df2])

    # if trial==0:
    #     continue
    df3=pd.DataFrame([[SymPop(G).eveness, SymPop(G).mean_fitness, SymPop(G).pop_size,SymPop(G).richness,'free-living',str(trial)] for G in time_series_freeliving[trial]],
                            columns=['eveness','mean_fitness','pop_size','richness','metapop','trial'])
    df3['code_version']='v1_4'
    df=pd.concat([df, df3])

axes[0,i].set_title('code_version='+'v1_4 '+'mutation_rate = '+str(mutation_rate))
sns.lineplot(ax=axes[0,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='richness',hue='metapop',style='code_version',legend=True)
sns.lineplot(ax=axes[1,i], data=df[(df.pop_size>0) & ~(df.eveness.isna())],x=df[(df.pop_size>0) & ~(df.eveness.isna())].index,y='eveness',hue='metapop',style='code_version',legend=False)
sns.lineplot(ax=axes[2,i], data=df[(df.pop_size>0)],x=df[(df.pop_size>0)].index,y='mean_fitness',hue='metapop',style='code_version',legend=False)
axes[0, i].set_ylim(0, 900)
axes[1, i].set_ylim(0, 0.8)
axes[2, i].set_ylim(0.5, 1.3)
fig.text(0.5, 0.04, 'Host pop generations', ha='center')
# Out:
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:131: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /data/qiulab/CRF_project/work/Modeling_trophosome/notebooks/../src/project_package/generate_pop.py:131: RuntimeWarning: divide by zero encountered in log
#   self.eveness=self.Shannon/np.log(self.richness)
# Text(0.5, 0.04, 'Host pop generations')

# %%
from project_package.generate_pop import SymPop

for k,G_list in myGs_free_living.items():
    print(k)
    plt.figure()
    SymPop(G_list[0]).visualize_pop(replace_title=k+'_'+"gen0",view_node_labels=False)
    plt.figure()
    SymPop(G_list[1]).visualize_pop(replace_title=k+'_'+"gen20",view_node_labels=False)
# Out:
# v2_2
# v1_4

# %% [markdown]
# ## Intra-host population

# %%
import seaborn as sns
mydf=df[(df.toy_example_id.isin(['1','10','11','12','13'])) & (df.variable=='run_time') & (df.n_worms==100)& (df.cpus==10)]
g = sns.FacetGrid(mydf, hue="code_version",col='code_version',sharey=True)
g.map(sns.lineplot,'intrahost_pop','value')
g.map(sns.scatterplot,'intrahost_pop','value')
g.set(yscale='log')
g.set(ylabel='Time (seconds)')
g.set(xscale='log')

g.add_legend(title="code_version")
# g.legend(title="host population size")
mydf
# Out:
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
# /home/qiulab/.conda/envs/mamba/envs/maeva_env/lib/python3.10/site-packages/seaborn/relational.py:292: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sub_data = grouped.apply(agg, other).reset_index()
#                               test  n_worms  cpus code_version toy_example_id  \
# 100   toy_example1_100worms_10cpus      100    10         v1_3              1
# 116  toy_example13_100worms_10cpus      100    10         v1_3             13
# 117  toy_example10_100worms_10cpus      100    10         v1_3             10
# 118  toy_example12_100worms_10cpus      100    10         v1_3             12
# 119  toy_example11_100worms_10cpus      100    10         v1_3             11
# 120  toy_example10_100worms_10cpus      100    10         v1_3             10
# 121   toy_example1_100worms_10cpus      100    10         v2_1              1
# 138   toy_example1_100worms_10cpus      100    10         v2_1              1
# 145  toy_example10_100worms_10cpus      100    10         v2_1             10
# 146  toy_example11_100worms_10cpus      100    10         v2_1             11
# 147  toy_example12_100worms_10cpus      100    10         v2_1             12
# 154   toy_example1_100worms_10cpus      100    10         v2_2              1
# 155   toy_example1_100worms_10cpus      100    10         v2_2              1
# 177   toy_example1_100worms_10cpus      100    10         v1_4              1
#
#      mutation_rate  intrahost_pop  variable         value
# 100   1.000000e-12        10000.0  run_time      5.594924
# 116   1.000000e-12    100000000.0  run_time     26.965534
# 117   1.000000e-12       100000.0  run_time     20.405120
# 118   1.000000e-12     10000000.0  run_time     23.858385
# 119   1.000000e-12      1000000.0  run_time     21.802859
# 120   1.000000e-12       100000.0  run_time     20.447577
# 121   1.000000e-12        10000.0  run_time     53.641718
# 138   1.000000e-12        10000.0  run_time     55.655686
# 145   1.000000e-12       100000.0  run_time    266.380995
# 146   1.000000e-12      1000000.0  run_time   4214.188127
# 147   1.000000e-12     10000000.0  run_time  65802.637636
# 154   1.000000e-12        10000.0  run_time     32.975580
# 155   1.000000e-12        10000.0  run_time     33.824805
# 177   1.000000e-12        10000.0  run_time     11.421731
